# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2086347903.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 df = pd.read_csv("/Users/garimss/Desktop/blockchain_integrated_ml/data/test.csv")
#       5 df.head()
#
# ...

# %%
df.columns[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4205715234.py in <cell line: 0>()
# ----> 1 df.columns[-1]
#
# NameError: name 'df' is not defined

# %%
X = df.drop("Activity", axis=1)
y = df["Activity"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2704172795.py in <cell line: 0>()
# ----> 1 X = df.drop("Activity", axis=1)
#       2 y = df["Activity"]
#
# NameError: name 'df' is not defined

# %%
X = X.fillna(X.median())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2110166747.py in <cell line: 0>()
# ----> 1 X = X.fillna(X.median())
#
# NameError: name 'X' is not defined

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3920448900.py in <cell line: 0>()
#       2
#       3 scaler = StandardScaler()
# ----> 4 X_scaled = scaler.fit_transform(X)
#
# NameError: name 'X' is not defined

# %%
np.save("/Users/garimss/Desktop/blockchain_integrated_ml/data/X_scaled.npy", X_scaled)
np.save("/Users/garimss/Desktop/blockchain_integrated_ml/data/y_clean.npy", y.values)

# %%
df.isnull().sum().sum()

# %%
numeric_df = df.select_dtypes(include=["float64", "int64"])
corr_sample = numeric_df.sample(n=50, axis=1)

plt.figure(figsize=(10,6))
sns.heatmap(corr_sample.corr(), cmap="coolwarm")
plt.title("Correlation (Sample of Features)")
plt.show()

# %%
for col in numeric_df.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower, upper)

print("Outliers capped using IQR method")

# %%
categorical_cols = df.select_dtypes(include=["object", "category"]).columns

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print("Categorical variables encoded using One-Hot Encoding")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2700068862.py in <cell line: 0>()
# ----> 1 categorical_cols = df.select_dtypes(include=["object", "category"]).columns
#       2
#       3 df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
#       4 print("Categorical variables encoded using One-Hot Encoding")
#
# NameError: name 'df' is not defined

# %%
numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
print(df.head())
print("Final shape:", df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-611446406.py in <cell line: 0>()
# ----> 1 numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns
#       2 scaler = StandardScaler()
#       3 df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
#       4 print(df.head())
#       5 print("Final shape:", df.shape)
#
# NameError: name 'df' is not defined

# %%
import numpy as np

X_scaled = np.load("X_scaled.npy")
X_meaned = X_scaled - np.mean(X_scaled, axis=0)
cov_matrix = np.cov(X_meaned.T)
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3258596044.py in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 X_scaled = np.load("X_scaled.npy")
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453             own_fid = False
#     454         else:
# --> 455             fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456             own_fid = True
#     457
#
# FileNotFoundError: [Errno 2] No such file or directory: 'X_scaled.npy'

# %%
idx = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]
explained_variance = eigenvalues / np.sum(eigenvalues)
cumulative_variance = np.cumsum(explained_variance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3702983288.py in <cell line: 0>()
# ----> 1 idx = np.argsort(eigenvalues)[::-1]
#       2 eigenvalues = eigenvalues[idx]
#       3 eigenvectors = eigenvectors[:, idx]
#       4 explained_variance = eigenvalues / np.sum(eigenvalues)
#       5 cumulative_variance = np.cumsum(explained_variance)
#
# NameError: name 'eigenvalues' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(cumulative_variance)
plt.xlabel("Component Count")
plt.ylabel("Cumulative Variance")
plt.title("PCA Variance (Scratch)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1237989220.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(cumulative_variance)
#       3 plt.xlabel("Component Count")
#       4 plt.ylabel("Cumulative Variance")
#       5 plt.title("PCA Variance (Scratch)")
#
# NameError: name 'cumulative_variance' is not defined

# %%
k = np.argmax(cumulative_variance >= 0.95) + 1
X_reduced_scratch = X_scaled @ eigenvectors[:, :k]

print("Reduced dims (scratch):", X_reduced_scratch.shape[1])
